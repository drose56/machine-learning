# %% [markdown]
# # CSE - 144 Assignment 4
#
# ## Due: June 7, 2022 11:59 pm
#
#
# **Be sure to set your Runtime environment to include a GPU, as it will speed up the training considerably (this time that's important!).**
#
# Intro Slides: https://docs.google.com/presentation/d/1PjqwL9g8XPr40LLRjRAAtxzc4Tf9iqVVnq61gJ59_Iw/edit?usp=sharing

# %%
# Ignore the warnings - Otherwise, TensorFlow tends to innundate one with far too many warnings.
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# Data visualizaton.
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
import random as rn

# Configure some defaults.
# %matplotlib inline  
style.use('fivethirtyeight')
sns.set(style='whitegrid',color_codes=True)

# ML + Deep Learning Imports
import tensorflow as tf
from keras import backend as k
from tensorflow import keras
from keras.regularizers import l2
from keras.preprocessing.image import ImageDataGenerator # Data Augmentation
from tensorflow.keras import regularizers 
from tensorflow.keras.models import Sequential # This building the models
from tensorflow.keras.layers import Dense, Dropout, Flatten, Activation, Conv2D, MaxPooling2D 
from tensorflow.keras.optimizers import Adam, SGD, Adagrad, Adadelta, RMSprop 
from tensorflow.keras.utils import to_categorical # if label is 0,1,...,99 etc then it becomes [0,...1,.,0] a len 100 vector

from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input

from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg19 import preprocess_input

from tensorflow.keras.applications.efficientnet import EfficientNetB2

from keras.callbacks import ReduceLROnPlateau #learning rate decay policy
from sklearn.model_selection import train_test_split # for splitting data

 

import numpy as np
import pandas as pd # for making our csv
import time
# Image preprocessing and reading in.
import imageio 
from pathlib import Path
import os, sys
from zipfile import ZipFile

# %% [markdown]
# #### Step-0: Import dataset
# Download Tiny-ImageNet-100 dataset using the code blocks below.
#
# Please fill in the code block below to split the data into training, validation and test datasets you may use scikit-learn to split.

# %%
# Download Tiny-Imagenet-100
# !gdown 1bn9RtCsMu-v_ZagKCK2z7hVEDOIjb9Pd
#!gdown 1iHvavfWWiWbSfVdM-xUDGwT3niD3o5W0

for file in os.listdir(os.getcwd()):
    if file.endswith(".zip"):
        zip = ZipFile(file)
        zip.extractall()
    else:
        print("not found")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1bn9RtCsMu-v_ZagKCK2z7hVEDOIjb9Pd
# To: /content/tiny-image-net-100.zip
# 100% 139M/139M [00:00<00:00, 200MB/s]
# not found
# not found

# %%
path = 'tiny-image-net-100/'

def get_id_dictionary():
  """
  Maps each class id to an unique integer.
  """
  id_dict = {}
  for i, line in enumerate(open( path + 'wnids.txt', 'r')):
      id_dict[line.replace('\n', '')] = i
  return id_dict
  
def get_class_to_id_dict():
  """
  Maps each class id to the English version of the label.
  """
  id_dict = get_id_dictionary()
  all_classes = {}
  result = {}
  for i, line in enumerate(open( path + 'words.txt', 'r')):
      n_id, word = line.split('\t')[:2]
      all_classes[n_id] = word
  for key, value in id_dict.items():
      result[value] = (key, all_classes[key])      
  return result

def get_data(id_dict, n_samples=10):
    """
    n_samples: number of samples per class. n_samples has a max of 500.
    The range is [1, 500].
    """
    print('starting loading data')
    train_data, test_data = [], []
    train_labels = []
    t = time.time()
    for key, value in id_dict.items():
      if value<100: # Only focus on first 100 classes
        train_data += [imageio.imread( path + 'train/{}/images/{}_{}.JPEG'.format(key, key, str(i)), pilmode='RGB') for i in range(n_samples)]
        train_labels_ = np.array([[0]*100]*n_samples)
        train_labels_[:, value] = 1
        train_labels += train_labels_.tolist()

    test_image_names = []
    path_list = list(Path(path+'test/images/').glob('*.jpg'))
    for test_image_path in path_list:
        img_name = str(test_image_path).split('.')[0][-18:]
        test_image_names.append(img_name)
        test_data.append(imageio.imread(test_image_path , pilmode='RGB'))
        
    print('finished loading data, in {} seconds'.format(time.time() - t))
    return np.array(train_data), np.array(train_labels), np.array(test_data), test_image_names

# %%
###### Your codes start here.######
# Start with n_samples = 10 to get your code working and then increase accordlingy.
d = get_id_dictionary()
train_data, train_labels, test_data, test_image_names = get_data(d, 500)
x_train, x_val, y_train, y_val = train_test_split(train_data, train_labels, test_size = 0.2, random_state = 56)
#x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size = 0.2, random_state = 56)
x_test = test_data
x_test_names = test_image_names
###### Your codes start here.######
print( "train data shape: ",  x_train.shape )
print( "train label shape: ", y_train.shape )
print( "val data shape: ",  x_val.shape )
print( "val label shape: ", y_val.shape )
print( "test data shape: ",   x_test.shape )
#print( "test data: ",   x_test)
#print( "test data: ",   x_test_names)
# Out:
# starting loading data
# finished loading data, in 20.000397205352783 seconds
# train data shape:  (40000, 64, 64, 3)
# train label shape:  (40000, 100)
# val data shape:  (10000, 64, 64, 3)
# val label shape:  (10000, 100)
# test data shape:  (5000, 64, 64, 3)

# %% [markdown]
# #### Step-1: Data Preparation & Exploration
#
# Let's take a look at a few of these images. Rerun this cell multiple times to see different images for each class.
#
# You may notice that these images look low fidelity, which is because they are! As we increase our image size, we also increase our model complexity. What's important is that our classes are still distinguishable from each other.

# %%
#Visulize one image from Tiny-ImageNet
plt.imshow(x_train[0], cmap=plt.cm.binary)
print(x_train[0].shape)
# Out:
# (64, 64, 3)

# %% [markdown]
# #### Step-2: Build a neural network.
# Build your convolutional neural networks by adding some layers. You should use 2 convolution layers and ReLU as the default activation function.
# Add max pooling after the first layer.
# The kernel size of both layers should be 3x3. Use 32 and 64 as the number of filters for the first and the second convolutional layers, respectively. After that, flatten your input and add two more dense layers. There should be 1024 units in the first dense with ReLU activation, and use 100 hidden units in the second dense layer with softmax activation.

# %%
###### Your code starts here. ######
from keras.models import Model   
from keras.layers import * 
from tensorflow.keras import layers, models

inputs = Input(shape = (64, 64, 3))

#myModel = VGG16(weights='imagenet', include_top=False, input_shape = (64, 64, 3), input_tensor = inputs, pooling = average)
myModel = EfficientNetB2(weights='imagenet', include_top=False, input_shape = (64, 64, 3), pooling = average)
vgg = myModel.output 
#vgg = Dropout(0.25)(vgg)
pool = GlobalAveragePooling2D()(vgg)

final = Dense(100)(pool)
final = Dropout(0.15)(final)
final = BatchNormalization(name = 'norm_6')(final)
final = Activation("softmax")(final)


model = Model(inputs = myModel.input, outputs = final)

data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal_and_vertical"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.1),
        layers.RandomContrast(0.1)
    ]
)


#x_train = preprocess_input(x_train)
#x_val = preprocess_input(x_val)
#x_test = preprocess_input(x_test)

x_train = data_augmentation(x_train)
x_val = data_augmentation(x_val)
x_test = data_augmentation(x_test)


###### Your codes end here.######
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb2_notop.h5
# 31793152/31790344 [==============================] - 0s 0us/step
# 31801344/31790344 [==============================] - 0s 0us/step

# %% [markdown]
# ### Side Note: How to save a model to google drive

# %%
# Mount colab to your drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Add load model if exists

# %%
# Save your model to gdrive
model.save('/content/drive/My Drive/hw4_model.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# load a model
# Returns a compiled model identical to the previous one, if you load you don't need to model.compile()
#model = load_model('/content/drive/My Drive/YOUR FOLDER NAME/hw4_model.h5')

# %% [markdown]
# #### Step-3: Train the model
# Compile model here and set your initial hyperparameters. Use ADAM as the optimizer. You should choose 'categorical_crossentropy' as your loss function, and the metrics should be 'accuracy'. After that, train your model for 30 epochs.

# %%
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1), cooldown=0, patience=5, min_lr=0.5e-3)

# %%
### Your code here###
#compile the model
model.compile(loss = keras.losses.categorical_crossentropy,
              optimizer = keras.optimizers.Adam(lr = 0.001),
              metrics =['accuracy'])
model.summary()

model.fit(x_train, y_train, epochs = 10, batch_size = 200, steps_per_epoch = len(x_train)//200, validation_data = (x_val, y_val), callbacks = [lr_reducer])

#train_datagen = ImageDataGenerator()
#valid_datagen = ImageDataGenerator()

#train_datagen.fit(x_train)
#valid_datagen.fit(x_val)

#model.fit_generator(train_datagen.flow(x_train, y_train, batch_size = 1), steps_per_epoch = 1, validation_data = valid_datagen.flow(x_val, y_val), epochs = 30, callbacks = [lr_reducer])

#model.fit(x_train, y_train, epochs = 30,)


# Do model.summary()
### Your code here###
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  rescaling (Rescaling)          (None, 64, 64, 3)    0           ['input_2[0][0]']
#
#  normalization (Normalization)  (None, 64, 64, 3)    7           ['rescaling[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 65, 65, 3)    0           ['normalization[0][0]']
#
#  stem_conv (Conv2D)             (None, 32, 32, 32)   864         ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalization)   (None, 32, 32, 32)   128         ['stem_conv[0][0]']
#
#  stem_activation (Activation)   (None, 32, 32, 32)   0           ['stem_bn[0][0]']
#
#  block1a_dwconv (DepthwiseConv2  (None, 32, 32, 32)  288         ['stem_activation[0][0]']
#  D)
#
#  block1a_bn (BatchNormalization  (None, 32, 32, 32)  128         ['block1a_dwconv[0][0]']
#  )
#
#  block1a_activation (Activation  (None, 32, 32, 32)  0           ['block1a_bn[0][0]']
#  )
#
#  block1a_se_squeeze (GlobalAver  (None, 32)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 32, 32, 32)   0           ['block1a_activation[0][0]',
#                                                                   'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 32, 32, 16)   512         ['block1a_se_excite[0][0]']
#
#  block1a_project_bn (BatchNorma  (None, 32, 32, 16)  64          ['block1a_project_conv[0][0]']
#  lization)
#
#  block1b_dwconv (DepthwiseConv2  (None, 32, 32, 16)  144         ['block1a_project_bn[0][0]']
#  D)
#
#  block1b_bn (BatchNormalization  (None, 32, 32, 16)  64          ['block1b_dwconv[0][0]']
#  )
#
#  block1b_activation (Activation  (None, 32, 32, 16)  0           ['block1b_bn[0][0]']
#  )
#
#  block1b_se_squeeze (GlobalAver  (None, 16)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 16)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 4)      68          ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 16)     80          ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 32, 32, 16)   0           ['block1b_activation[0][0]',
#                                                                   'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 32, 32, 16)   256         ['block1b_se_excite[0][0]']
#
#  block1b_project_bn (BatchNorma  (None, 32, 32, 16)  64          ['block1b_project_conv[0][0]']
#  lization)
#
#  block1b_drop (Dropout)         (None, 32, 32, 16)   0           ['block1b_project_bn[0][0]']
#
#  block1b_add (Add)              (None, 32, 32, 16)   0           ['block1b_drop[0][0]',
#                                                                   'block1a_project_bn[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 32, 32, 96)   1536        ['block1b_add[0][0]']
#
#  block2a_expand_bn (BatchNormal  (None, 32, 32, 96)  384         ['block2a_expand_conv[0][0]']
#  ization)
#
#  block2a_expand_activation (Act  (None, 32, 32, 96)  0           ['block2a_expand_bn[0][0]']
#  ivation)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 33, 33, 96)  0           ['block2a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 16, 16, 96)  864         ['block2a_dwconv_pad[0][0]']
#  D)
#
#  block2a_bn (BatchNormalization  (None, 16, 16, 96)  384         ['block2a_dwconv[0][0]']
#  )
#
#  block2a_activation (Activation  (None, 16, 16, 96)  0           ['block2a_bn[0][0]']
#  )
#
#  block2a_se_squeeze (GlobalAver  (None, 96)          0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 96)     0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 4)      388         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 96)     480         ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 16, 16, 96)   0           ['block2a_activation[0][0]',
#                                                                   'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 16, 16, 24)   2304        ['block2a_se_excite[0][0]']
#
#  block2a_project_bn (BatchNorma  (None, 16, 16, 24)  96          ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 16, 16, 144)  3456        ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 16, 16, 144)  576        ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 16, 16, 144)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_dwconv (DepthwiseConv2  (None, 16, 16, 144)  1296       ['block2b_expand_activation[0][0]
#  D)                                                              ']
#
#  block2b_bn (BatchNormalization  (None, 16, 16, 144)  576        ['block2b_dwconv[0][0]']
#  )
#
#  block2b_activation (Activation  (None, 16, 16, 144)  0          ['block2b_bn[0][0]']
#  )
#
#  block2b_se_squeeze (GlobalAver  (None, 144)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 16, 16, 144)  0           ['block2b_activation[0][0]',
#                                                                   'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 16, 16, 24)   3456        ['block2b_se_excite[0][0]']
#
#  block2b_project_bn (BatchNorma  (None, 16, 16, 24)  96          ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 16, 16, 24)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 16, 16, 24)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 16, 16, 144)  3456        ['block2b_add[0][0]']
#
#  block2c_expand_bn (BatchNormal  (None, 16, 16, 144)  576        ['block2c_expand_conv[0][0]']
#  ization)
#
#  block2c_expand_activation (Act  (None, 16, 16, 144)  0          ['block2c_expand_bn[0][0]']
#  ivation)
#
#  block2c_dwconv (DepthwiseConv2  (None, 16, 16, 144)  1296       ['block2c_expand_activation[0][0]
#  D)                                                              ']
#
#  block2c_bn (BatchNormalization  (None, 16, 16, 144)  576        ['block2c_dwconv[0][0]']
#  )
#
#  block2c_activation (Activation  (None, 16, 16, 144)  0          ['block2c_bn[0][0]']
#  )
#
#  block2c_se_squeeze (GlobalAver  (None, 144)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 16, 16, 144)  0           ['block2c_activation[0][0]',
#                                                                   'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 16, 16, 24)   3456        ['block2c_se_excite[0][0]']
#
#  block2c_project_bn (BatchNorma  (None, 16, 16, 24)  96          ['block2c_project_conv[0][0]']
#  lization)
#
#  block2c_drop (Dropout)         (None, 16, 16, 24)   0           ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)              (None, 16, 16, 24)   0           ['block2c_drop[0][0]',
#                                                                   'block2b_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 16, 16, 144)  3456        ['block2c_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 16, 16, 144)  576        ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 16, 16, 144)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 19, 19, 144)  0          ['block3a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 8, 8, 144)   3600        ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 8, 8, 144)   576         ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 8, 8, 144)   0           ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 144)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 8, 8, 144)    0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 8, 8, 48)     6912        ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 8, 8, 48)    192         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 8, 8, 288)    13824       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 8, 8, 288)   1152        ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 8, 8, 288)   0           ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 8, 8, 288)   7200        ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 8, 8, 288)   1152        ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 8, 8, 288)   0           ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 288)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 8, 8, 288)    0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 8, 8, 48)     13824       ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 8, 8, 48)    192         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 8, 8, 48)     0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 8, 8, 48)     0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 8, 8, 288)    13824       ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 8, 8, 288)   1152        ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 8, 8, 288)   0           ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_dwconv (DepthwiseConv2  (None, 8, 8, 288)   7200        ['block3c_expand_activation[0][0]
#  D)                                                              ']
#
#  block3c_bn (BatchNormalization  (None, 8, 8, 288)   1152        ['block3c_dwconv[0][0]']
#  )
#
#  block3c_activation (Activation  (None, 8, 8, 288)   0           ['block3c_bn[0][0]']
#  )
#
#  block3c_se_squeeze (GlobalAver  (None, 288)         0           ['block3c_activation[0][0]']
#  agePooling2D)
#
#  block3c_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block3c_se_squeeze[0][0]']
#
#  block3c_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multiply)   (None, 8, 8, 288)    0           ['block3c_activation[0][0]',
#                                                                   'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv2D)  (None, 8, 8, 48)     13824       ['block3c_se_excite[0][0]']
#
#  block3c_project_bn (BatchNorma  (None, 8, 8, 48)    192         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 8, 8, 48)     0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 8, 8, 48)     0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 8, 8, 288)    13824       ['block3c_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 8, 8, 288)   1152        ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 8, 8, 288)   0           ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv_pad (ZeroPaddin  (None, 9, 9, 288)   0           ['block4a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block4a_dwconv (DepthwiseConv2  (None, 4, 4, 288)   2592        ['block4a_dwconv_pad[0][0]']
#  D)
#
#  block4a_bn (BatchNormalization  (None, 4, 4, 288)   1152        ['block4a_dwconv[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 4, 4, 288)   0           ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 288)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 4, 4, 288)    0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 4, 4, 88)     25344       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 4, 4, 88)    352         ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 4, 4, 528)    46464       ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 4, 4, 528)   2112        ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 4, 4, 528)   0           ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv (DepthwiseConv2  (None, 4, 4, 528)   4752        ['block4b_expand_activation[0][0]
#  D)                                                              ']
#
#  block4b_bn (BatchNormalization  (None, 4, 4, 528)   2112        ['block4b_dwconv[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 4, 4, 528)   0           ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 528)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 528)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 22)     11638       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 528)    12144       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 4, 4, 528)    0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 4, 4, 88)     46464       ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 4, 4, 88)    352         ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 4, 4, 88)     0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 4, 4, 88)     0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 4, 4, 528)    46464       ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 4, 4, 528)   2112        ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 4, 4, 528)   0           ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv (DepthwiseConv2  (None, 4, 4, 528)   4752        ['block4c_expand_activation[0][0]
#  D)                                                              ']
#
#  block4c_bn (BatchNormalization  (None, 4, 4, 528)   2112        ['block4c_dwconv[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 4, 4, 528)   0           ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 528)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 528)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 22)     11638       ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 528)    12144       ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, 4, 4, 528)    0           ['block4c_activation[0][0]',
#                                                                   'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, 4, 4, 88)     46464       ['block4c_se_excite[0][0]']
#
#  block4c_project_bn (BatchNorma  (None, 4, 4, 88)    352         ['block4c_project_conv[0][0]']
#  lization)
#
#  block4c_drop (Dropout)         (None, 4, 4, 88)     0           ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)              (None, 4, 4, 88)     0           ['block4c_drop[0][0]',
#                                                                   'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2D)   (None, 4, 4, 528)    46464       ['block4c_add[0][0]']
#
#  block4d_expand_bn (BatchNormal  (None, 4, 4, 528)   2112        ['block4d_expand_conv[0][0]']
#  ization)
#
#  block4d_expand_activation (Act  (None, 4, 4, 528)   0           ['block4d_expand_bn[0][0]']
#  ivation)
#
#  block4d_dwconv (DepthwiseConv2  (None, 4, 4, 528)   4752        ['block4d_expand_activation[0][0]
#  D)                                                              ']
#
#  block4d_bn (BatchNormalization  (None, 4, 4, 528)   2112        ['block4d_dwconv[0][0]']
#  )
#
#  block4d_activation (Activation  (None, 4, 4, 528)   0           ['block4d_bn[0][0]']
#  )
#
#  block4d_se_squeeze (GlobalAver  (None, 528)         0           ['block4d_activation[0][0]']
#  agePooling2D)
#
#  block4d_se_reshape (Reshape)   (None, 1, 1, 528)    0           ['block4d_se_squeeze[0][0]']
#
#  block4d_se_reduce (Conv2D)     (None, 1, 1, 22)     11638       ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)     (None, 1, 1, 528)    12144       ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multiply)   (None, 4, 4, 528)    0           ['block4d_activation[0][0]',
#                                                                   'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv2D)  (None, 4, 4, 88)     46464       ['block4d_se_excite[0][0]']
#
#  block4d_project_bn (BatchNorma  (None, 4, 4, 88)    352         ['block4d_project_conv[0][0]']
#  lization)
#
#  block4d_drop (Dropout)         (None, 4, 4, 88)     0           ['block4d_project_bn[0][0]']
#
#  block4d_add (Add)              (None, 4, 4, 88)     0           ['block4d_drop[0][0]',
#                                                                   'block4c_add[0][0]']
#
#  block5a_expand_conv (Conv2D)   (None, 4, 4, 528)    46464       ['block4d_add[0][0]']
#
#  block5a_expand_bn (BatchNormal  (None, 4, 4, 528)   2112        ['block5a_expand_conv[0][0]']
#  ization)
#
#  block5a_expand_activation (Act  (None, 4, 4, 528)   0           ['block5a_expand_bn[0][0]']
#  ivation)
#
#  block5a_dwconv (DepthwiseConv2  (None, 4, 4, 528)   13200       ['block5a_expand_activation[0][0]
#  D)                                                              ']
#
#  block5a_bn (BatchNormalization  (None, 4, 4, 528)   2112        ['block5a_dwconv[0][0]']
#  )
#
#  block5a_activation (Activation  (None, 4, 4, 528)   0           ['block5a_bn[0][0]']
#  )
#
#  block5a_se_squeeze (GlobalAver  (None, 528)         0           ['block5a_activation[0][0]']
#  agePooling2D)
#
#  block5a_se_reshape (Reshape)   (None, 1, 1, 528)    0           ['block5a_se_squeeze[0][0]']
#
#  block5a_se_reduce (Conv2D)     (None, 1, 1, 22)     11638       ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)     (None, 1, 1, 528)    12144       ['block5a_se_reduce[0][0]']
#
# ...
#                                                                   'block6d_se_expand[0][0]']
#
#  block6d_project_conv (Conv2D)  (None, 2, 2, 208)    259584      ['block6d_se_excite[0][0]']
#
#  block6d_project_bn (BatchNorma  (None, 2, 2, 208)   832         ['block6d_project_conv[0][0]']
#  lization)
#
#  block6d_drop (Dropout)         (None, 2, 2, 208)    0           ['block6d_project_bn[0][0]']
#
#  block6d_add (Add)              (None, 2, 2, 208)    0           ['block6d_drop[0][0]',
#                                                                   'block6c_add[0][0]']
#
#  block6e_expand_conv (Conv2D)   (None, 2, 2, 1248)   259584      ['block6d_add[0][0]']
#
#  block6e_expand_bn (BatchNormal  (None, 2, 2, 1248)  4992        ['block6e_expand_conv[0][0]']
#  ization)
#
#  block6e_expand_activation (Act  (None, 2, 2, 1248)  0           ['block6e_expand_bn[0][0]']
#  ivation)
#
#  block6e_dwconv (DepthwiseConv2  (None, 2, 2, 1248)  31200       ['block6e_expand_activation[0][0]
#  D)                                                              ']
#
#  block6e_bn (BatchNormalization  (None, 2, 2, 1248)  4992        ['block6e_dwconv[0][0]']
#  )
#
#  block6e_activation (Activation  (None, 2, 2, 1248)  0           ['block6e_bn[0][0]']
#  )
#
#  block6e_se_squeeze (GlobalAver  (None, 1248)        0           ['block6e_activation[0][0]']
#  agePooling2D)
#
#  block6e_se_reshape (Reshape)   (None, 1, 1, 1248)   0           ['block6e_se_squeeze[0][0]']
#
#  block6e_se_reduce (Conv2D)     (None, 1, 1, 52)     64948       ['block6e_se_reshape[0][0]']
#
#  block6e_se_expand (Conv2D)     (None, 1, 1, 1248)   66144       ['block6e_se_reduce[0][0]']
#
#  block6e_se_excite (Multiply)   (None, 2, 2, 1248)   0           ['block6e_activation[0][0]',
#                                                                   'block6e_se_expand[0][0]']
#
#  block6e_project_conv (Conv2D)  (None, 2, 2, 208)    259584      ['block6e_se_excite[0][0]']
#
#  block6e_project_bn (BatchNorma  (None, 2, 2, 208)   832         ['block6e_project_conv[0][0]']
#  lization)
#
#  block6e_drop (Dropout)         (None, 2, 2, 208)    0           ['block6e_project_bn[0][0]']
#
#  block6e_add (Add)              (None, 2, 2, 208)    0           ['block6e_drop[0][0]',
#                                                                   'block6d_add[0][0]']
#
#  block7a_expand_conv (Conv2D)   (None, 2, 2, 1248)   259584      ['block6e_add[0][0]']
#
#  block7a_expand_bn (BatchNormal  (None, 2, 2, 1248)  4992        ['block7a_expand_conv[0][0]']
#  ization)
#
#  block7a_expand_activation (Act  (None, 2, 2, 1248)  0           ['block7a_expand_bn[0][0]']
#  ivation)
#
#  block7a_dwconv (DepthwiseConv2  (None, 2, 2, 1248)  11232       ['block7a_expand_activation[0][0]
#  D)                                                              ']
#
#  block7a_bn (BatchNormalization  (None, 2, 2, 1248)  4992        ['block7a_dwconv[0][0]']
#  )
#
#  block7a_activation (Activation  (None, 2, 2, 1248)  0           ['block7a_bn[0][0]']
#  )
#
#  block7a_se_squeeze (GlobalAver  (None, 1248)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 1248)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 52)     64948       ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 1248)   66144       ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 2, 2, 1248)   0           ['block7a_activation[0][0]',
#                                                                   'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 2, 2, 352)    439296      ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 2, 2, 352)   1408        ['block7a_project_conv[0][0]']
#  lization)
#
#  block7b_expand_conv (Conv2D)   (None, 2, 2, 2112)   743424      ['block7a_project_bn[0][0]']
#
#  block7b_expand_bn (BatchNormal  (None, 2, 2, 2112)  8448        ['block7b_expand_conv[0][0]']
#  ization)
#
#  block7b_expand_activation (Act  (None, 2, 2, 2112)  0           ['block7b_expand_bn[0][0]']
#  ivation)
#
#  block7b_dwconv (DepthwiseConv2  (None, 2, 2, 2112)  19008       ['block7b_expand_activation[0][0]
#  D)                                                              ']
#
#  block7b_bn (BatchNormalization  (None, 2, 2, 2112)  8448        ['block7b_dwconv[0][0]']
#  )
#
#  block7b_activation (Activation  (None, 2, 2, 2112)  0           ['block7b_bn[0][0]']
#  )
#
#  block7b_se_squeeze (GlobalAver  (None, 2112)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 2112)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 88)     185944      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 2112)   187968      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, 2, 2, 2112)   0           ['block7b_activation[0][0]',
#                                                                   'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 2, 2, 352)    743424      ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 2, 2, 352)   1408        ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_drop (Dropout)         (None, 2, 2, 352)    0           ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)              (None, 2, 2, 352)    0           ['block7b_drop[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#
#  top_conv (Conv2D)              (None, 2, 2, 1408)   495616      ['block7b_add[0][0]']
#
#  top_bn (BatchNormalization)    (None, 2, 2, 1408)   5632        ['top_conv[0][0]']
#
#  top_activation (Activation)    (None, 2, 2, 1408)   0           ['top_bn[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1408)        0           ['top_activation[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 100)          140900      ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dropout (Dropout)              (None, 100)          0           ['dense[0][0]']
#
#  norm_6 (BatchNormalization)    (None, 100)          400         ['dropout[0][0]']
#
#  activation (Activation)        (None, 100)          0           ['norm_6[0][0]']
#
# ==================================================================================================
# Total params: 7,909,869
# Trainable params: 7,842,094
# Non-trainable params: 67,775
# __________________________________________________________________________________________________
# Epoch 1/10
# 200/200 [==============================] - 74s 230ms/step - loss: 2.7503 - accuracy: 0.3934 - val_loss: 1.7253 - val_accuracy: 0.5812 - lr: 0.0010
# Epoch 2/10
# 200/200 [==============================] - 46s 232ms/step - loss: 1.8031 - accuracy: 0.5879 - val_loss: 1.5373 - val_accuracy: 0.6298 - lr: 0.0010
# Epoch 3/10
# 200/200 [==============================] - 45s 224ms/step - loss: 1.4597 - accuracy: 0.6624 - val_loss: 1.5000 - val_accuracy: 0.6445 - lr: 0.0010
# Epoch 4/10
# 200/200 [==============================] - 45s 225ms/step - loss: 1.2475 - accuracy: 0.7106 - val_loss: 1.5350 - val_accuracy: 0.6408 - lr: 0.0010
# Epoch 5/10
# 200/200 [==============================] - 45s 227ms/step - loss: 1.0974 - accuracy: 0.7407 - val_loss: 1.5301 - val_accuracy: 0.6474 - lr: 0.0010
# Epoch 6/10
# 200/200 [==============================] - 47s 237ms/step - loss: 1.0018 - accuracy: 0.7617 - val_loss: 1.5889 - val_accuracy: 0.6428 - lr: 0.0010
# Epoch 7/10
# 200/200 [==============================] - 45s 227ms/step - loss: 0.9256 - accuracy: 0.7747 - val_loss: 1.6072 - val_accuracy: 0.6444 - lr: 0.0010
# Epoch 8/10
# 200/200 [==============================] - 47s 237ms/step - loss: 0.8681 - accuracy: 0.7882 - val_loss: 1.6607 - val_accuracy: 0.6334 - lr: 0.0010
# Epoch 9/10
# 200/200 [==============================] - 45s 227ms/step - loss: 0.7031 - accuracy: 0.8263 - val_loss: 1.4542 - val_accuracy: 0.6764 - lr: 5.0000e-04
# Epoch 10/10
# 200/200 [==============================] - 47s 236ms/step - loss: 0.6291 - accuracy: 0.8410 - val_loss: 1.4742 - val_accuracy: 0.6784 - lr: 5.0000e-04

# %% [markdown]
# ### Data Augmentation
#
# There are many augmentations you can use! Read about them in the Keras documentation.
#
#  **Rescale is very important!**

# %%
# Set up data generators for training and validation set
# add transformations

#datagen = ImageDataGenerator(
          #rescale=1/255.,
          #featurewise_center=False,           # set input mean to 0 over the dataset
          #samplewise_center=False,            # set each sample mean to 0
          #featurewise_std_normalization=False,# divide inputs by std of the dataset
          #samplewise_std_normalization=False, # divide each input by its std
          #zca_whitening=False,                # apply ZCA whitening
          #rotation_range=0,                   # randomly rotate images in the range (degrees, 0 to 180)
          #width_shift_range=0.1,              # randomly shift images horizontally (fraction of total width)
          #height_shift_range=0.1,             # randomly shift images vertically (fraction of total height)
          #horizontal_flip=True,               # randomly flip images
          #vertical_flip=True)               # randomly flip images



#train_datagen = ImageDataGenerator(rescale = 1/255., featurewise_center = True, samplewise_center=True, featurewise_std_normalization=True, samplewise_std_normalization=True)
#valid_datagen = ImageDataGenerator(rescale=1/255., featurewise_center = True, samplewise_center=True, featurewise_std_normalization=True, samplewise_std_normalization=True)
#test_datagen = ImageDataGenerator(rescale=1/255., featurewise_center = True, samplewise_center=True, featurewise_std_normalization=True, samplewise_std_normalization=True)

# %%
### Your code here ###
# fit generators to datasetsc

#train_datagen.fit(x_train, augment = True)
#valid_datagen.fit(x_val, augment = True)
#test_datagen.fit(x_test, augment = True)
#print()

#model.fit_generator(train_datagen.flow(x_train, y_train, batch_size = 100), steps_per_epoch = len(x_train) // 100, validation_data = valid_datagen.flow(x_val, y_val), epochs = 10, callbacks = [lr_reducer])

#model.fit(x_train, y_train, epochs = 30,)




### Your code here###

# %%
## Your Code Here ###
#set number of epochs
#set batch_size
#nb_epoch = 100
#batch_size = 10
# Fit the model on the batches generated by datagen.flow().
#model.fit(train_datagen.flow(x_train, y_train, batch_size=200),
         #validation_data=valid_datagen.flow(x_val, y_val,
         #batch_size=50),
         #steps_per_epoch=len(x_train) / 200, epochs=30)
#model.fit_generator(train_datagen.flow(x_train, y_train, batch_size = 200), steps_per_epoch = len(x_train) // 200, validation_data = valid_datagen.flow(x_val, y_val), epochs = 10, callbacks = [lr_reducer])
#model.fit_generator(train_datagen.flow(x_train, y_train, batch_size = 10), steps_per_epoch = 1, validation_data = valid_datagen.flow(x_val, y_val), epochs = 300, callbacks = [lr_reducer])
#history = # fit model using fit_generator
## Your Code Here ###

# %% [markdown]
# ### Plot Model Performance

# %%
# Plot Model Performance
### YOUR CODE HERE ###
model.evaluate(x_val, y_val)
# Out:
# 313/313 [==============================] - 10s 23ms/step - loss: 1.4742 - accuracy: 0.6784
# [1.4741861820220947, 0.6783999800682068]

# %%
# Make Submission Kaggle File
def create_submission_file(model):
  name2idx = {}
  sample_submission = pd.read_csv('tiny-image-net-100/submission_sample.csv')
  filename_order = sample_submission['img_id'].values
  for i in range(len(filename_order)):
    name2idx[filename_order[i]] = i

  # Google colab reads the files in a different order than the answer file was created.
  # This is done to preserve the file order.
  result_dict = {'img_id': [None]*len(x_test),
                'label':[None]*len(x_test)}
  test_preds = np.argmax(model.predict(x_test),axis=-1)
  for i in range(len(x_test_names)):
    test_image_name = x_test_names[i]
    result_dict['img_id'][name2idx[test_image_name]] = test_image_name
    result_dict['label'][name2idx[test_image_name]] = test_preds[i]

  pd.DataFrame(result_dict).to_csv('submission.csv', index=False)

# %%
# Create your submission file and download it.
## Your Code Here ###
#print(model.predict(x_test))
create_submission_file(model)
# Out:
# [39 48 88 ... 10  2 55]

# %% [markdown]
# You made it this far! You may have noticed your accuracy is not that great to improve on it do the following:
#
# i) Design a more complex neural network architecture. (Transfer learning may help)
#
# ii) Utilize data augmentation during training.
#
#
# Experiment often and save your models.
#
# When you are satisfied submit your predictions to Kaggle.
#
# Good luck!
